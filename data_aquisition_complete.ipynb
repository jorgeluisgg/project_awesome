# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import csv


# Get the list of NASDAQ companies
nasdaq_tickers = pd.read_csv('nasdaq_screener.csv')
#nasdaq_tickers= pd.read_csv('https://datahub.io/core/nasdaq-listings/r/nasdaq-listed-symbols.csv')
tickers_total = nasdaq_tickers['Symbol'].tolist()
tickers = tickers_total[0:3534]

# Prepare the CSV file
header_written = False
csv_file = 'nasdaq_financial_data.csv'


# Helper function to get the stock price on a specific date
def get_stock_price(ticker, date, stock):
    stock_data = stock.history(start=date, end=date + timedelta(days=7))
    for i in range(7):        
        try:
            adjusted_date = date + timedelta(days=i)
            stock_data_l = stock.history(start=adjusted_date, end=adjusted_date+timedelta(days=1))
            if not stock_data_l.empty:
                return stock_data_l['Close'].iloc[0]
        except Exception as e: 
            print(f"get_stock_price : Error processing ticker {ticker}: {e}")


!
# Function that flattens the data of a dataframe concatenate the columns and put everything in a row
def flatten_data(df, ticker):    
    
    df_u = df.unstack().reset_index()
    df_u['Ticker'] = df_u.apply(lambda row: str(row['level_0'].year) + ' ' + row['level_1'], axis=1)
    df_u.set_index(keys = 'Ticker')
    df_ordered = df_u.drop(columns = ['level_0','level_1'])
    df_transposed = df_ordered.set_index(keys='Ticker').T
    df_transposed['Ticker'] = ticker
    df_transposed.set_index(keys='Ticker',inplace = True)  
    
    return df_transposed


#Compute the stock value ratio (item_stock%/sp500_stock%) in a year
def get_stock_value_ratio(date, ticker, stock, stock_sp):
    for i in range(7):
        try:
            # Adjust date by i days
            adjusted_date = date + timedelta(days=i)
            stock_data = get_stock_price(ticker, adjusted_date, stock)

            if stock_data is not None:
                date_diff = adjusted_date - timedelta(weeks=52)
                #change in s&p 500 price in %
                sp500_change = get_stock_price("^GSPC", adjusted_date, stock_sp) / get_stock_price("^GSPC",date_diff, stock_sp)
                #change in stock price in %
                stock_change = get_stock_price(ticker,adjusted_date, stock)/ get_stock_price(ticker,date_diff, stock)
                #ratio of change_stock / change_s&p500
                ratio = stock_change / sp500_change
                if ratio is not None:
                    return ratio
        except Exception as e:
            print(f"get_stock_value_ratio : Error processing ticker {ticker}: {e}")

#function to get the stock value corresponding to the date date

def get_stock_value(df, ticker, stock, stock_sp) :
    lst_stock_value = []
    lst_stock_ratio = []
    for date in df.columns :
        date_str = date.strftime('%Y-%m-%d')
        lst_stock_value.append(get_stock_price(ticker, date, stock))
        lst_stock_ratio.append(get_stock_value_ratio(date, ticker, stock, stock_sp))
        
    df.loc['Stock value'] = lst_stock_value
    df.loc['Ratio ticker sp500'] = lst_stock_ratio
    return df

def create_df(tickers):
    stock_sp = yf.Ticker('^GSPC')
    df_complete = pd.DataFrame()
    for ticker in tickers:  
        df_row = pd.DataFrame()
        try: 
            # Get financial statements for the ticker ticker
            stock = yf.Ticker(ticker)
            balance_sheet = stock.balance_sheet
            income_statement = stock.financials
            cashflow_statement = stock.cashflow
            #stock_history = stock.history
            
            # add the stock value and flatten the dataframe
            #df_bs = get_stock_value(balance_sheet,ticker, stock, stock_sp)
            df_bs_f = flatten_data(balance_sheet,ticker)
            df_is_f = flatten_data(income_statement,ticker)
            df_cs_f = flatten_data(cashflow_statement,ticker)
            #concatenate
            df_row = pd.concat([df_bs_f,df_is_f,df_cs_f],axis=1)
            df_complete = pd.concat([df_complete, df_row])
    
        except Exception as e: 
            print(f"create_df : Error processing ticker {ticker}: {e}")
    return df_complete

# %%
len(tickers_total)/2
# Out:
# 3534.5

# %%
# %%time 
df = create_df(tickers_total)
df.to_csv('data_stock_f.csv')
# Out:
# create_df : Error processing ticker ABR^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ABR^E: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ABR^F: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ACAB: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker ACABU: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker ACABW: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker ACP^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ACR^C: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ACR^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ADC^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ADX: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AEFC: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AENT: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker AENTW: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker AFGB: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AFGC: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AFGD: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AFGE: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AFJKU: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AGD: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AGM^C: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AGM^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AGM^E: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AGM^F: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AGM^G: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHH^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHL^C: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHL^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHL^E: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHT^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHT^F: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHT^G: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHT^H: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AHT^I: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AIZN: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AKO/A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AKO/B: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AL^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALB^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALL^B: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALL^H: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALL^I: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALL^J: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALSAR: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ALTG^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AMH^G: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AMH^H: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AMIX: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ANG^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ANG^B: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AOD: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker APO^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker APOS: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AQNB: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ARBKL: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ARDC: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker ARGD: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ARGO^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ARR^C: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ASA: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ASB^E: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ASB^F: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ASBA: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ASG: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ASGI: Reindexing only valid with uniquely valued Index objects
# create_df : Error processing ticker ATCO^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATCO^H: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATCOL: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATH^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATH^B: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATH^C: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATH^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATH^E: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATHS: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATLCL: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATLCZ: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATMCR: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker ATMVR: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AUB^A: Cannot set a DataFrame with multiple columns to the single column Ticker
# create_df : Error processing ticker AULT^D: Cannot set a DataFrame with multiple columns to the single column Ticker
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[56], line 91, in create_df(tickers)
#      89 balance_sheet = stock.balance_sheet
#      90 income_statement = stock.financials
# ---> 91 cashflow_statement = stock.cashflow
#      92 #stock_history = stock.history
#      93
#      94 # add the stock value and flatten the dataframe
#      95 #df_bs = get_stock_value(balance_sheet,ticker, stock, stock_sp)
#      96 df_bs_f = flatten_data(balance_sheet,ticker)
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/ticker.py:236, in Ticker.cashflow(self)
#     234 @property
#     235 def cashflow(self) -> _pd.DataFrame:
# --> 236     return self.cash_flow
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/ticker.py:228, in Ticker.cash_flow(self)
#     226 @property
#     227 def cash_flow(self) -> _pd.DataFrame:
# --> 228     return self.get_cash_flow(pretty=True, freq="yearly")
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/base.py:381, in TickerBase.get_cash_flow(self, proxy, as_dict, pretty, freq)
#     364 """
#     365 :Parameters:
#     366     as_dict: bool
#    (...)
#     377         Default is None
#     378 """
#     379 self._fundamentals.proxy = proxy or self.proxy
# --> 381 data = self._fundamentals.financials.get_cash_flow_time_series(freq=freq, proxy=proxy)
#     383 if pretty:
#     384     data = data.copy()
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:67, in Financials.get_cash_flow_time_series(self, freq, proxy)
#      65 res = self._cash_flow_time_series
#      66 if freq not in res:
# ---> 67     res[freq] = self._fetch_time_series("cash-flow", freq, proxy)
#      68 return res[freq]
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:85, in Financials._fetch_time_series(self, name, timescale, proxy)
#      82     raise ValueError(f"Illegal argument: timescale must be one of: {allowed_timescales}")
#      84 try:
# ---> 85     statement = self._create_financials_table(name, timescale, proxy)
#      87     if statement is not None:
#      88         return statement
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:101, in Financials._create_financials_table(self, name, timescale, proxy)
#      98 keys = const.fundamentals_keys[name]
#     100 try:
# --> 101     return self.get_financials_time_series(timescale, keys, proxy)
#     102 except Exception:
#     103     pass
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/scrapers/fundamentals.py:118, in Financials.get_financials_time_series(self, timescale, keys, proxy)
#     115 url += f"&period1={int(start_dt.timestamp())}&period2={int(end.timestamp())}"
#     117 # Step 3: fetch and reshape data
# --> 118 json_str = self._data.cache_get(url=url, proxy=proxy).text
#     119 json_data = json.loads(json_str)
#     120 data_raw = json_data["timeseries"]["result"]
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/data.py:28, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      26 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      27 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 28 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/data.py:386, in YfData.cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     383 @lru_cache_freezeargs
#     384 @lru_cache(maxsize=cache_maxsize)
#     385 def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 386     return self.get(url, user_agent_headers, params, proxy, timeout)
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/yfinance/data.py:366, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     356     cookies = None
#     358 request_args = {
#     359     'url': url,
#     360     'params': {**params, **crumbs},
#    (...)
#     364     'headers': user_agent_headers or self.user_agent_headers
#     365 }
# --> 366 response = self._session.get(**request_args)
#     367 utils.get_yf_logger().debug(f'response code={response.status_code}')
#     368 if response.status_code >= 400:
#     369     # Retry with other cookie strategy
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df_['2023 Ratio ticker sp500']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2023 Ratio ticker sp500'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_['2023 Ratio ticker sp500']
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.6/envs/project_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '2023 Ratio ticker sp500'
