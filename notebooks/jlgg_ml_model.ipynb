# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import yfinance as yf
# from project_awesome.data.preprocessing import preprocessing_the_data

# %%
#Imports
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_selector
from sklearn.compose import make_column_transformer

#CLEANING THE DATA:

#drop columns that have more than 30% of missing data:
def remove_shitty_columns(df):
    for column in df.columns:
        if df[column].isnull().sum()/len(df) > 0.3:
            df.drop(columns=[column], inplace=True)
    return df


#drop rows that have more than 30% of missing values
def remove_shitty_rows(df):
    threshold = 0.3 * df.shape[1]  # Calculate the threshold for missing values
    df = df.dropna(thresh=int(df.shape[1] - threshold))
    return df

#FINAL CLEANING FUNCTION
def clean_dataframe(df):
    df = remove_shitty_columns(df)
    df = remove_shitty_rows(df)
    df = df.reset_index(drop=True)
    return df


#PREPROCESSING
def preprocessing_the_data(df):
    #use simple impute with strategy = "constant"
    imputer = SimpleImputer(strategy="constant", fill_value=0)

    #Robust Scaler to Scale data because of outliers
    rb_scaler = RobustScaler()

    #select numerical columns
    num_transformer = make_pipeline(imputer, rb_scaler)
    num_columns = make_column_selector(dtype_exclude="object")

    #Create Preproc Pipeline
    preproc_basic = make_column_transformer((num_transformer, num_columns))

    #Apply Preprocessing to dataframe
    preprocessed_data = preproc_basic.fit_transform(df)

    #Change column names of transformed dataframe
    df_preproc = pd.DataFrame(preprocessed_data, columns=preproc_basic.get_feature_names_out())

    #Merge with tickers
    df_preproc = df_preproc.join(df.Ticker)

    return df_preproc


"""to import in the other file:

from preprocessing import clean_dataframe, preprocessing_the_data

df = clean_dataframe(df)
df = propcessing_the_data(df)

"""
# Out:
# 'to import in the other file:\n\nfrom preprocessing import clean_dataframe, preprocessing_the_data\n\ndf = clean_dataframe(df)\ndf = propcessing_the_data(df)\n\n'

# %%
df  = pd.read_csv('/home/jorgeluisgg/code/jorgeluisgg/project_awesome/raw_data/Raw_data_number_one.csv')

# %%
df
# Out:
#      Ticker  2023 Treasury Shares Number  2023 Ordinary Shares Number  \
# 0       AAL                          0.0                 6.542732e+08
# 1      AAME                          NaN                          NaN
# 2      AAOI                          NaN                 3.814800e+07
# 3      AAON                          NaN                 8.150838e+07
# 4      AAPL                          0.0                 1.555006e+10
# ...     ...                          ...                          ...
# 1763   ZKIN                          NaN                          NaN
# 1764   ZLAB                    4912200.0                 9.722391e+08
# 1765     ZS                          NaN                 1.471690e+08
# 1766   ZUMZ                          NaN                 1.948900e+07
# 1767   true                          NaN                 9.109154e+07
#
#       2023 Share Issued  2023 Net Debt  2023 Total Debt  \
# 0          6.542732e+08   3.232400e+10     4.066300e+10
# 1                   NaN            NaN              NaN
# 2          3.814800e+07   6.983200e+07     1.210730e+08
# 3          8.150838e+07   3.804100e+07     5.055000e+07
# 4          1.555006e+10   8.112300e+10     1.110880e+11
# ...                 ...            ...              ...
# 1763                NaN            NaN              NaN
# 1764       9.771513e+08            NaN     1.515100e+07
# 1765       1.471690e+08            NaN     1.210545e+09
# 1766       1.948900e+07            NaN     2.542950e+08
# 1767       9.109154e+07            NaN     1.440900e+07
#
#       2023 Tangible Book Value  2023 Invested Capital  2023 Working Capital  \
# 0                -1.134400e+10           2.770000e+10         -8.490000e+09
# 1                          NaN                    NaN                   NaN
# 2                 2.062110e+08           3.300670e+08          7.924700e+07
# 3                 5.852790e+08           7.735520e+08          2.822050e+08
# 4                 6.214600e+10           1.732340e+11         -1.742000e+09
# ...                        ...                    ...                   ...
# 1763                       NaN                    NaN                   NaN
# 1764              7.796600e+08           7.961180e+08          7.365390e+08
# 1765              6.100610e+08           1.859271e+09          1.354446e+09
# 1766              3.363190e+08           4.073280e+08          1.943690e+08
# 1767              1.518400e+08           1.602150e+08          1.341040e+08
#
#       2023 Net Tangible Assets  ...  2024 Interest Paid Cff  \
# 0                -1.134400e+10  ...                     NaN
# 1                          NaN  ...                     NaN
# 2                 2.062110e+08  ...                     NaN
# 3                 5.852790e+08  ...                     NaN
# 4                 6.214600e+10  ...                     NaN
# ...                        ...  ...                     ...
# 1763                       NaN  ...                     NaN
# 1764              7.796600e+08  ...                     NaN
# 1765              6.100610e+08  ...                     NaN
# 1766              3.363190e+08  ...                     NaN
# 1767              1.518400e+08  ...                     NaN
#
#       2024 Interest Received Cfi  2024 Taxes Refund Paid  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ...                          ...                     ...
# 1763                         NaN                     NaN
# 1764                         NaN                     NaN
# 1765                         NaN                     NaN
# 1766                         NaN                     NaN
# 1767                         NaN                     NaN
#
#       2024 Earnings From Equity Interest Net Of Tax  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 1763                                            NaN
# 1764                                            NaN
# 1765                                            NaN
# 1766                                            NaN
# 1767                                            NaN
#
#       2024 Rent Expense Supplemental  2024 Rent And Landing Fees  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# ...                              ...                         ...
# 1763                             NaN                         NaN
# 1764                             NaN                         NaN
# 1765                             NaN                         NaN
# 1766                             NaN                         NaN
# 1767                             NaN                         NaN
#
#       2019 Depletion Income Statement  2024 Financial Assets  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
# ...                               ...                    ...
# 1763                              NaN                    NaN
# 1764                              NaN                    NaN
# 1765                              NaN                    NaN
# 1766                              NaN                    NaN
# 1767                              NaN                    NaN
#
#       2024 Cash From Discontinued Financing Activities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1763                                               NaN
# 1764                                               NaN
# 1765                                               NaN
# 1766                                               NaN
# 1767                                               NaN
#
#       2024 Accrued Interest Receivable
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 1763                               NaN
# 1764                               NaN
# 1765                               NaN
# 1766                          409000.0
# 1767                               NaN
#
# [1768 rows x 2000 columns]

# %%
df = clean_dataframe(df)
df = preprocessing_the_data(df)

# %%
df
# Out:
#       pipeline__2023 Ordinary Shares Number  pipeline__2023 Share Issued  \
# 0                                  8.004987                     7.515304
# 1                                  0.018042                    -0.022246
# 2                                  0.580131                     0.508216
# 3                                201.101827                   189.747335
# 4                                  0.418674                     0.398206
# ...                                     ...                          ...
# 1644                              -0.476477                    -0.488941
# 1645                              12.126837                    11.465329
# 1646                               1.431302                     1.311495
# 1647                              -0.223838                    -0.250516
# 1648                               0.704359                     0.625455
#
#       pipeline__2023 Total Debt  pipeline__2023 Tangible Book Value  \
# 0                     55.734768                          -23.148653
# 1                     -0.007525                            0.157374
# 2                     -0.104489                            0.922258
# 3                    152.564180                          125.139545
# 4                      0.705827                            4.428940
# ...                         ...                                 ...
# 1644                  -0.173992                           -0.258718
# 1645                  -0.153160                            1.314480
# 1646                   1.490422                            0.972263
# 1647                   0.175646                            0.419906
# 1648                  -0.154180                            0.047664
#
#       pipeline__2023 Invested Capital  pipeline__2023 Working Capital  \
# 0                           15.145524                      -27.907990
# 1                           -0.075072                        0.088309
# 2                            0.171553                        0.751386
# 3                           96.077914                       -5.861826
# 4                            2.002865                       -0.170596
# ...                               ...                             ...
# 1644                        -0.258624                       -0.170596
# 1645                         0.184102                        2.235725
# 1646                         0.775329                        4.254469
# 1647                        -0.032106                        0.464420
# 1648                        -0.169527                        0.267530
#
#       pipeline__2023 Net Tangible Assets  \
# 0                             -23.064565
# 1                               0.156803
# 2                               0.918908
# 3                             124.684969
# 4                               4.412852
# ...                                  ...
# 1644                           -0.257779
# 1645                            1.309705
# 1646                            0.968732
# 1647                            0.418381
# 1648                            0.047491
#
#       pipeline__2023 Capital Lease Obligations  \
# 0                                   139.337965
# 1                                    -0.045400
# 2                                     0.068675
# 3                                    -0.150992
# 4                                    -0.150992
# ...                                        ...
# 1644                                 -0.150992
# 1645                                  0.121318
# 1646                                  1.221899
# 1647                                  4.419469
# 1648                                  0.107982
#
#       pipeline__2023 Common Stock Equity  pipeline__2023 Total Capitalization  \
# 0                              -5.430906                            13.420363
# 1                              -0.056036                            -0.088785
# 2                               0.460284                             0.185325
# 3                              61.394917                            89.189982
# 4                               3.130939                             2.056340
# ...                                  ...                                  ...
# 1644                           -0.269239                            -0.254178
# 1645                            0.520706                             0.198146
# 1646                            0.450251                             0.802190
# 1647                            0.134931                            -0.022750
# 1648                           -0.110266                            -0.163150
#
#       ...  pipeline__2022 Change In Payable  \
# 0     ...                         -0.012340
# 1     ...                          1.987660
# 2     ...                          1.772945
# 3     ...                       1457.337652
# 4     ...                          1.745180
# ...   ...                               ...
# 1644  ...                          1.345662
# 1645  ...                         -8.306802
# 1646  ...                          2.202375
# 1647  ...                         -2.967916
# 1648  ...                         -0.436526
#
#       pipeline__2022 Change In Account Payable  \
# 0                                    -0.008001
# 1                                     2.297475
# 2                                     2.049964
# 3                                  1679.935100
# 4                                     1.097440
# ...                                        ...
# 1644                                  1.557419
# 1645                                 -9.569346
# 1646                                  2.544986
# 1647                                 -2.508001
# 1648                                 -0.496977
#
#       pipeline__2022 Changes In Account Receivables  \
# 0                                          0.046615
# 1                                         -0.930844
# 2                                         -4.270337
# 3                                       -139.721843
# 4                                         -1.496358
# ...                                             ...
# 1644                                      -0.877990
# 1645                                       0.378594
# 1646                                     -10.942881
# 1647                                       0.046615
# 1648                                       0.216055
#
#       pipeline__2021 Change In Payable  \
# 0                            -0.026416
# 1                             0.723637
# 2                             1.129854
# 3                          1307.633248
# 4                             0.592086
# ...                                ...
# 1644                         -0.953617
# 1645                          6.712603
# 1646                          0.764057
# 1647                          2.349883
# 1648                         -0.218014
#
#       pipeline__2021 Change In Account Payable  \
# 0                                    -0.013996
# 1                                     0.877317
# 2                                     1.360232
# 3                                  1554.140588
# 4                                    -0.162149
# ...                                        ...
# 1644                                 -1.106238
# 1645                                  7.995335
# 1646                                  0.925482
# 1647                                  2.608246
# 1648                                 -0.241710
#
#       pipeline__2021 Changes In Account Receivables  \
# 0                                          0.022523
# 1                                         -0.650278
# 2                                         -0.910677
# 3                                       -970.362756
# 4                                          1.875791
# ...                                             ...
# 1644                                       0.578844
# 1645                                      -4.033353
# 1646                                     -10.673759
# 1647                                       0.022523
# 1648                                       1.525781
#
#       pipeline__2020 Change In Payable  \
# 0                             0.000000
# 1                            -0.959839
# 2                            -0.618187
# 3                         -1165.232358
# 4                            -5.191624
# ...                                ...
# 1644                          1.558635
# 1645                         11.469019
# 1646                          0.247275
# 1647                          0.000000
# 1648                         -2.358290
#
#       pipeline__2020 Change In Account Payable  \
# 0                                     0.000000
# 1                                    -1.144274
# 2                                    -0.736752
# 3                                 -1388.717949
# 4                                    -2.063590
# ...                                        ...
# 1644                                  1.908645
# 1645                                 13.668718
# 1646                                  0.294701
# 1647                                  0.000000
# 1648                                 -2.810598
#
#       pipeline__2020 Changes In Account Receivables  Ticker
# 0                                          0.000000     AAL
# 1                                         -1.871333    AAOI
# 2                                          4.413111    AAON
# 3                                       1537.111111    AAPL
# 4                                         -5.309333    ABCB
# ...                                             ...     ...
# 1644                                      -1.066864    ZKIN
# 1645                                      -0.305556    ZLAB
# 1646                                     -12.049333      ZS
# 1647                                       0.000000    ZUMZ
# 1648                                       0.518222    true
#
# [1649 rows x 440 columns]

# %%
names = pd.read_csv('/home/jorgeluisgg/code/jorgeluisgg/project_awesome/raw_data/nasdaq_screener.csv')
tickers_list = names[names.columns[0]].tolist()
tickers = [str(ticker) for ticker in tickers_list if "^" not in str(ticker)]
stocks = []
# Loop to fetch object for each ticker
for ticker in tickers:
    # Append the object to the list
    stocks.append(yf.Ticker(ticker))

# %%
prices = pd.read_csv('/home/jorgeluisgg/code/jorgeluisgg/project_awesome/raw_data/stock_prices_1y.csv')
prices
