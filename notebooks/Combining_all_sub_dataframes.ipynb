# %% [markdown]
# # Final Raw Data Frame

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("../raw_data/Raw_data_new_version_part_one_Garrit.csv")

# %%
df_1
# Out:
#      Ticker  2023 Ordinary Shares Number  2023 Share Issued  2023 Net Debt  \
# 0         A                  292123241.0        292123241.0   1.145000e+09
# 1        AA                  178472464.0        178472464.0   8.670000e+08
# 2      AACG                   64000260.0         64585618.0            NaN
# 3      AACI                    8072849.0          8072849.0   2.504155e+06
# 4     AACIW                    8072849.0          8072849.0   2.504155e+06
# ...     ...                          ...                ...            ...
# 1514   CULP                   12327414.0         12327414.0            NaN
# 1515   CURI                   53286000.0         53286000.0            NaN
# 1516  CURIW                   53286000.0         53286000.0            NaN
# 1517   CURV                  103774813.0        103774813.0   3.156520e+08
# 1518   CUTR                   19948803.0         19948803.0   2.750830e+08
#
# ...

# %%
df_2 = pd.read_csv("../raw_data/Raw_data_new_version_part_two_Guillaume.csv")

# %%
df_2
# Out:
#      Ticker  2023 Treasury Shares Number  2023 Ordinary Shares Number  \
# 0       CUZ                    2536583.0                 1.517992e+08
# 1      CVAC                          NaN                 2.239887e+08
# 2      CVBF                          0.0                 1.393450e+08
# 3      CVCO                     671801.0                 8.665324e+06
# 4       CVE                          0.0                 1.871869e+09
# ...     ...                          ...                          ...
# 1620   KAVL                          0.0                 2.793385e+06
# 1621     KB                   24847247.0                 3.786638e+08
# 1622   KBDC                          NaN                 6.502164e+07
# 1623    KBH                   25408951.0                 7.586703e+07
# 1624    KBR                   46646024.0                 1.350676e+08
#
#       2023 Share Issued  2023 Net Debt  2023 Total Debt  \
# 0          1.543358e+08   2.451580e+09     2.510975e+09
# ...

# %%
df_3 = pd.read_csv("../raw_data/Raw_data_new_version_part_three_Jorge.csv")

# %%
df_3
# Out:
#      Ticker  2023 Treasury Shares Number  2023 Ordinary Shares Number  \
# 0        KC                  243187335.0                 3.562097e+09
# 1      KCGI                          0.0                 1.144273e+07
# 2        KD                    1900000.0                 2.277000e+08
# 3       KDP                          NaN                 1.390446e+09
# 4        KE                    4706000.0                 2.472400e+07
# ...     ...                          ...                          ...
# 1592   RAIL                          NaN                 1.790344e+07
# 1593   RAMP                   87400000.0                 6.660000e+07
# 1594   RAND                      67895.0                 2.581021e+06
# 1595   RANI                          NaN                 2.603600e+07
# 1596   RAPT                          NaN                 3.439831e+07
#
#       2023 Share Issued  2023 Total Debt  2023 Tangible Book Value  \
# ...

# %%
df_4 = pd.read_csv("../raw_data/Raw_data_new_version_part_four_Manon.csv")

# %%
df_4
# Out:
#      Ticker  2023 Treasury Shares Number  2023 Ordinary Shares Number  \
# 0      RARE                       9559.0                   82315590.0
# 1      RAVE                   10935605.0                   14154453.0
# 2       RAY                          NaN                   17500000.0
# 3      RAYA                          NaN                   12450000.0
# 4       RBA                          0.0                  182843942.0
# ...     ...                          ...                          ...
# 1588   ZVIA                          0.0                   54220017.0
# 1589   ZVRA                          NaN                          NaN
# 1590   ZVSA                          6.0                     405205.0
# 1591   ZYME                          NaN                   70115997.0
# 1592   ZYXI                    8545044.0                   32933776.0
#
#       2023 Share Issued  2023 Total Debt  2023 Tangible Book Value  \
# ...

# %%
#concat_df= pd.concat([a_df, b_df], axis="index", sort=False)`
#add parameter `ignore_index=True` so they are stacked

# %%
raw_df = pd.concat([df_1, df_2, df_3, df_4], axis="index", sort=False, ignore_index=True)
raw_df
# Out:
#      Ticker  2023 Ordinary Shares Number  2023 Share Issued  2023 Net Debt  \
# 0         A                  292123241.0        292123241.0   1.145000e+09
# 1        AA                  178472464.0        178472464.0   8.670000e+08
# 2      AACG                   64000260.0         64585618.0            NaN
# 3      AACI                    8072849.0          8072849.0   2.504155e+06
# 4     AACIW                    8072849.0          8072849.0   2.504155e+06
# ...     ...                          ...                ...            ...
# 6329   ZVIA                   54220017.0         54220017.0            NaN
# 6330   ZVRA                          NaN                NaN            NaN
# 6331   ZVSA                     405205.0           405211.0            NaN
# 6332   ZYME                   70115997.0         70115997.0            NaN
# 6333   ZYXI                   32933776.0         41478820.0   1.302600e+07
#
# ...

# %%
raw_df.to_csv("../raw_data/raw_data_FINAL_ALL.csv", index=False)

# %%
pd.read_csv("../raw_data/raw_data_FINAL_ALL.csv")
# Out:
#      Ticker  2023 Ordinary Shares Number  2023 Share Issued  2023 Net Debt  \
# 0         A                  292123241.0        292123241.0   1.145000e+09
# 1        AA                  178472464.0        178472464.0   8.670000e+08
# 2      AACG                   64000260.0         64585618.0            NaN
# 3      AACI                    8072849.0          8072849.0   2.504155e+06
# 4     AACIW                    8072849.0          8072849.0   2.504155e+06
# ...     ...                          ...                ...            ...
# 6329   ZVIA                   54220017.0         54220017.0            NaN
# 6330   ZVRA                          NaN                NaN            NaN
# 6331   ZVSA                     405205.0           405211.0            NaN
# 6332   ZYME                   70115997.0         70115997.0            NaN
# 6333   ZYXI                   32933776.0         41478820.0   1.302600e+07
#
# ...
